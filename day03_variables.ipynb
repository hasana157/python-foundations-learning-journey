# %%
# dynamic typing (python knows by itself the data type)  data type is not binded to specific variable

name="nith"
print(name)
# Out:
# nith

# %%
# static typing .specify the data type
name=4
print(name)
# Out:
# 4

# %%
# multiple variables multiple syntax
a=5;b=6
a,b,c=4,5,6
a=b=c=6
